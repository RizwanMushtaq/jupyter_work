# %% [raw]
# Hello Python Expressions

# %%
print(11//2)
# Out:
# 5

# %%
x = 4
print(x/2)
# Out:
# 2.0

# %%
print(25 / 5)
# Out:
# 5.0

# %%
print(25 // 5)
# Out:
# 5

# %%
print(24 // 5)
# Out:
# 4

# %%
x = 100
y = x / 60
print(y)
# Out:
# 1.6666666666666667
