# %% [markdown]
# # APIs and data collection

# %%
import requests

# %%
url = 'https://www.ibm.com/'
r = requests.get(url)
r
# Out:
# <Response [200]>

# %%
r.status_code
# Out:
# 200

# %%
r.headers
# Out:
# {'Content-Security-Policy': 'upgrade-insecure-requests', 'x-frame-options': 'SAMEORIGIN', 'Last-Modified': 'Mon, 06 Jul 2026 07:22:13 GMT', 'ETag': '"2f9c4-655ec2225fc1e-gzip"', 'Accept-Ranges': 'bytes', 'Content-Type': 'text/html;charset=utf-8', 'X-Content-Type-Options': 'nosniff', 'Cache-Control': 'max-age=23', 'Expires': 'Mon, 06 Jul 2026 07:39:45 GMT', 'X-Akamai-Transformed': '0 - 0 -', 'Content-Encoding': 'gzip', 'Date': 'Mon, 06 Jul 2026 07:39:22 GMT', 'Content-Length': '40479', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding', 'Strict-Transport-Security': 'max-age=31536000'}

# %%
r.encoding
# Out:
# 'utf-8'

# %%
r.text[0:100]
# Out:
# ' \n<!DOCTYPE HTML>\n\n<html lang="en">\n<head>\r\n    \r\n      \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n      '

# %%
r.url
# Out:
# 'https://www.ibm.com/us-en'

# %% [markdown]
# # Web Scraping and HTML Basics

# %% [markdown]
# Web scraping, also known as web harvesting or web data extraction, is the process of extracting information from websites or web pages. It involves automated retrieval of data from web sources. People use it for various applications such as data analysis, mining, price comparison, content aggregation, and more.

# %%
import requests
from bs4 import BeautifulSoup

# Specify the URL of the webpage you want to scrape
url = 'https://www.rizwanmushtaq.com/article/dsa-binary-tree-traversals-dfs-vs-bfs'

# Send an HTTP GET request to the webpage
response = requests.get(url)

# Store the HTML content in a variable
html_content = response.text

# Create a BeautifulSoup object to parse the HTML
soup = BeautifulSoup(html_content, 'html.parser')

soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8" data-next-head=""/><title data-next-head="">DSA - Binary Tree Traversals - DFS Vs BFS</title><meta content="DSA - Binary Tree Traversals - DFS Vs BFS" data-next-head="" property="og:title"/><meta content="article" data-next-head="" property="og:type"/><meta content="In this blog, I would like to share a traversal recipes for Binary Tree, including depth first search and breath first search which is also known as level order traversal." data-next-head="" property="og:description"/><meta content="https://images.ctfassets.net/wyek3u84nw85/5EkPK5D0G8Vr6cBaVXZnLZ/240b37db7ecda0465164db05ff2ed8d8/og_blog_banners.png" data-next-head="" property="og:image"/><meta content="https://www.rizwanmushtaq.com/article/dsa-binary-tree-traversals-dfs-vs-bfs" data-next-head="" property="og:url"/><meta content="rizwanmushtaqdhudhaal" data-next-head="" property="fb:app_id"/><meta content="summary_large_image" data-next-head="" name="twitter:card"/><meta content="DSA - Binary Tree Traversals - DFS Vs BFS" data-next-head="" name="twitter:title"/><meta content="In this blog, I would like to share a traversal recipes for Binary Tree, including depth first search and breath first search which is also known as level order traversal." data-next-head="" name="twitter:description"/><meta content="https://images.ctfassets.net/wyek3u84nw85/5EkPK5D0G8Vr6cBaVXZnLZ/240b37db7ecda0465164db05ff2ed8d8/og_blog_banners.png" data-next-head="" name="twitter:image"/><meta content="Rizwan Mushtaq" data-next-head="" property="og:site_name"/><meta content="Rizwan Mushtaq" data-next-head="" name="author"/><base data-next-head="" href="/"/><meta content="width=device-width, initial-scale=1" data-next-head="" name="viewport"/><link data-next-head="" href="/favicon.svg" rel="icon"/><link as="style" href="/_next/static/css/83624a2fb7bce90b.css" rel="preload"/><link data-n-g="" href="/_next/static/css/83624a2fb7bce90b.css" rel="stylesheet"/><noscript data-n-css=""></noscript><script defer="" nomodule="" src="/_next/static/chunks/polyfills-42372ed130431b0a.js"></script><script defer="" src="/_next/static/chunks/webpack-6ffd07a3317375c1.js"></script><script defer="" src="/_next/static/chunks/framework-37f3832b4337c515.js"></script><script defer="" src="/_next/static/chunks/main-7b20253d3ae031d9.js"></script><script defer="" src="/_next/static/chunks/pages/_app-570fc8104741d319.js"></script><script defer="" src="/_next/static/chunks/8-b6baefef4dabb518.js"></script><script defer="" src="/_next/static/chunks/417-8d093ad537d0b6ee.js"></script><script defer="" src="/_next/static/chunks/516-fbcf243ba8b0ad45.js"></script><script defer="" src="/_next/static/chunks/pages/article/%5Bslug%5D-c9d462a9d9b78fb7.js"></script><script defer="" src="/_next/static/K-hdsbzOvmCPBDA-kzFyj/_buildManifest.js"></script><script defer="" src="/_next/static/K-hdsbzOvmCPBDA-kzFyj/_ssgManifest.js"></script></head><body><div id="__next"><div class="body-overlay-1"></div><header class="header sticky-bar bg-gray-900"><div class="container"><div class="main-header"><div class="header-logo"><a class="d-flex" href="/"><svg id="logo_svg__Layer_1" style="enable-background:new 0 0 116 36" viewbox="0 0 116 36" x="0" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" y="0"><style>.logo_svg__st0,.logo_svg__st1{display:none;fill:#0ea5ea}.logo_svg__st1{opacity:.3;enable-background:new}.logo_svg__st6{fill:#d8e6fb}</style><path d="m3 9.7 12.3-6.8 12.4 6.8v14.4l-12.4 7.1L3 24.1z" style="fill:#fff;stroke:#0ea5ea;stroke-miterlimit:10"></path><path d="m27.8 10.1-12.4 6.8v14.5L27.8 24z" style="opacity:0.3;fill:#0ea5ea"></path><path class="logo_svg__st6" d="M36.2 11.3v6.4H34V2.9h6c3.1 0 4.7 1.7 4.7 4 0 1.9-1.1 3.1-2.5 3.5 1.1.3 2.2 1.2 2.2 3.8v.7c0 1 0 2.3.2 2.9h-2.1c-.3-.6-.3-1.8-.3-3.2v-.3c0-2-.6-2.9-3.2-2.9h-2.8zm0-1.8h3.1c2.2 0 3.1-.8 3.1-2.4 0-1.5-1-2.4-2.9-2.4h-3.3v4.8zM50.2 2.9v14.9H48V2.9h2.2zM52.8 16.1l8.9-11.3h-8.5V2.9h11v1.8l-8.7 11.2h9l-.3 1.9H52.8v-1.7zM69.3 17.8l-4-14.9h ...
#   int data;
#   TreeNode left, right;
#
#   public TreeNode(int data) {
#     this.data = data;
#     left = right = null;
#   }
# }
#
# /**
#    * Depth-first search is a type of traversal that goes deep as much as possible in every child
#    * before exploring the next sibling.
#    *
#    * &lt;p&gt;There are several ways to perform a depth-first search: in-order, pre-order and post-order.
#    */
#
#   /**
#    * The in-order traversal consists of first visiting the left sub-tree, then the root node, and finally the right sub-tree:
#    */
#   public void traverseInOrder(TreeNode node) {
#     if (node == null) return;
#     traverseInOrder(node.left);
#     System.out.print(" " + node.data);
#     traverseInOrder(node.right);
#   }
#
#   /**
#    * Pre-order traversal visits first the root node, then the left sub-tree and finally the right sub-tree.
#    */
#   public void traversePreOrder(TreeNode node) {
#     if (node == null) return;
#     System.out.print(" " + node.data);
#     traversePreOrder(node.left);
#     traversePreOrder(node.right);
#   }
#
#   /**
#    * Post.order traversal visits the left sub-tree, the right sub-tree and the root node at the end.
#    */
#   public void traversePostOrder(TreeNode node) {
#     if (node == null) return;
#     traversePostOrder(node.left);
#     traversePostOrder(node.right);
#     System.out.print(" " + node.data);
#   }
#
#   /**
#    * Breadth-First Search - This is another common type of traversal that visits all the nodes of a
#    * level before going to the next level.
#    *
#    * &lt;p&gt;This kind of traversal is also called level-order, and visits all the levels of the tree
#    * starting from the root, and from left to right.
#    *
#    * &lt;p&gt;For the implementation, we’ll use a Queue to hold the nodes from each level in order. We’ll extract each node from the list, print its values, then add its children to the queue:
#    */
#   public void traverseLevelOrder(TreeNode node) {
#     Queue&lt;TreeNode&gt; nodes = new LinkedList&lt;&gt;();
#     nodes.add(node);
#     while (!nodes.isEmpty()) {
#       TreeNode n = nodes.remove();
#       if (n == null) {
#         continue;
#       }
#       System.out.print(" " + n.data);
#       nodes.add(n.left);
#       nodes.add(n.right);
#     }
#   }
# </code></pre></div><p class="text-lg color-gray-500 mb-50"></p></div><div class="box-tags"><span class="text-sm mr-15">#dsa</span></div></div></div></div></div></div></main><footer class="footer"><div class="footer-1"><div class="text-base color-white wow animate__animated animate__fadeIn"><p class="copyright">© <!-- -->2026<!-- --> Rizwan Mushtaq</p></div><div><div class="box-socials"><div class="d-inline-block wow animate__animated animate__fadeIn" data-wow-delay=".2s"><a class="icon-socials icon-linked color-gray-500" href="https://www.linkedin.com/in/rizwanmushtaq15/" target="_blank">LinkedIn</a></div></div></div></div></footer></div><script id="__NEXT_DATA__" type="application/json">{"props":{"pageProps":{"article":{"metadata":{"tags":[],"concepts":[]},"sys":{"space":{"sys":{"type":"Link","linkType":"Space","id":"wyek3u84nw85"}},"id":"3fRSMY6IjDfy5LZn7tHbHr","type":"Entry","createdAt":"2025-11-26T19:35:49.563Z","updatedAt":"2025-11-26T19:35:49.563Z","environment":{"sys":{"id":"master","type":"Link","linkType":"Environment"}},"publishedVersion":54,"revision":1,"contentType":{"sys":{"type":"Link","linkType":"ContentType","id":"blogPost-2"}},"locale":"en-US"},"fields":{"thumbnail":{"metadata":{"tags":[],"concepts":[]},"sys":{"space":{"sys":{"type":"Link","linkType":"Space","id":"wyek3u84nw85"}},"id":"7MZilpnNNbN0kliaxY3SjU","type":"Asset","createdAt":"2025-11-26T19:35:13.748Z","updatedAt":"2025-11-26T19:35:13.748Z","environment":{"sys":{"id":"master","type":"Link","linkType":"Environment"}},"publishedVersion":5,"revision":1,"locale":"en-US"},"fields":{"title":"dsa-binary-tree-traversals-dfs-vs-bfs-thumbnail","description":"","file":{"url":"//images.ctfassets.net/wyek3u84nw85/7MZilpnNNbN0kliaxY3SjU/62ff2ad3de61be6a59e2dd10dca76ad0/posts_thumbnails.png","details":{"size":11201,"image":{"width":271,"height":258}},"fileName":"posts thumbnails.png","contentType":"image/png"}}},"coverImage":{"metadata":{"tags":[],"concepts":[]},"sys":{"space":{"sys":{"type":"Link","linkType":"Space","id":"wyek3u84nw85"}},"id":"5EkPK5D0G8Vr6cBaVXZnLZ","type":"Asset","createdAt":"2025-11-26T19:35:39.674Z","updatedAt":"2025-11-26T19:35:39.674Z","environment":{"sys":{"id":"master","type":"Link","linkType":"Environment"}},"publishedVersion":4,"revision":1,"locale":"en-US"},"fields":{"title":"dsa-binary-tree-traversals-dfs-vs-bfs-banner","description":"","file":{"url":"//images.ctfassets.net/wyek3u84nw85/5EkPK5D0G8Vr6cBaVXZnLZ/240b37db7ecda0465164db05ff2ed8d8/og_blog_banners.png","details":{"size":36150,"image":{"width":1200,"height":630}},"fileName":"og blog banners.png","contentType":"image/png"}}},"title":"DSA - Binary Tree Traversals - DFS Vs BFS","slug":"dsa-binary-tree-traversals-dfs-vs-bfs","categories":["DSA"],"tags":["#dsa"],"shortDescription":"In this blog, I would like to share a traversal recipes for Binary Tree, including depth first search and breath first search which is also known as level order traversal.","richTextBody":{"data":{},"content":[{"data":{},"content":[{"data":{},"marks":[],"value":"A binary tree is a recursive data structure where each node can have two children at most.","nodeType":"text"}],"nodeType":"paragraph"},{"data":{},"content":[{"data":{},"marks":[],"value":"Each node in a Binary Tree has three parts:","nodeType":"text"}],"nodeType":"heading-5"},{"data":{},"content":[{"data":{},"content":[{"data":{},"content":[{"data":{},"marks":[],"value":"Data","nodeType":"text"}],"nodeType":"paragraph"}],"nodeType":"list-item"},{"data":{},"content":[{"data":{},"content":[{"data":{},"marks":[],"value":"Pointer to the left child","nodeType":"text"}],"nodeType":"paragraph"}],"nodeType":"list-item"},{"data":{},"content":[{"data":{},"content":[{"data":{},"marks":[],"value":"Pointer to the right child","nodeType":"text"}],"nodeType":"paragraph"}],"nodeType":"list-item"}],"nodeType":"unordered-list"},{"data":{},"content":[{"data":{},"marks":[],"value":"Properties of Binary Tree","nodeType":"text"}],"nodeType":"heading-5"},{"data":{},"c ...

# %%
# Display a snippet of the HTML content
html_content[:500]
# Out:
# '<!DOCTYPE html><html lang="en"><head><meta charSet="utf-8" data-next-head=""/><title data-next-head="">DSA - Binary Tree Traversals - DFS Vs BFS</title><meta property="og:title" content="DSA - Binary Tree Traversals - DFS Vs BFS" data-next-head=""/><meta property="og:type" content="article" data-next-head=""/><meta property="og:description" content="In this blog, I would like to share a traversal recipes for Binary Tree, including depth first search and breath first search which is also known as'

# %%
links = soup.find_all('a')

for link in links:
    print(link.text)
# Out:
# Blog
# About Me
# LinkedIn
# GitHub
#
# Blog
# About Me
# LinkedIn
# GitHub
# Blog
# LinkedIn

# %%
# !pip install bs4
# !pip install requests pandas
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: beautifulsoup4 in C:\Users\rizwa\AppData\Local\Programs\Python\Python313\Lib\site-packages (from bs4) (4.15.0)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Users\rizwa\AppData\Local\Programs\Python\Python313\Lib\site-packages (from beautifulsoup4->bs4) (2.8.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in C:\Users\rizwa\AppData\Local\Programs\Python\Python313\Lib\site-packages (from beautifulsoup4->bs4) (4.15.0)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: requests in C:\Users\rizwa\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.34.2)
# Requirement already satisfied: pandas in C:\Users\rizwa\AppData\Local\Programs\Python\Python313\Lib\site-packages (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\rizwa\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\rizwa\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\rizwa\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\rizwa\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests) (2026.2.25)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\rizwa\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\rizwa\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\rizwa\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\rizwa\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
html="<!DOCTYPE html><html><head><title>Page Title</title></head><body><h3><b id='boldest'>Lebron James</b></h3><p> Salary: $ 92,000,000 </p><h3> Stephen Curry</h3><p> Salary: $85,000, 000 </p><h3> Kevin Durant </h3><p> Salary: $73,200, 000</p></body></html>"
soup = BeautifulSoup(html, 'html.parser')
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html>\n <head>\n  <title>\n   Page Title\n  </title>\n </head>\n <body>\n  <h3>\n   <b id="boldest">\n    Lebron James\n   </b>\n  </h3>\n  <p>\n   Salary: $ 92,000,000\n  </p>\n  <h3>\n   Stephen Curry\n  </h3>\n  <p>\n   Salary: $85,000, 000\n  </p>\n  <h3>\n   Kevin Durant\n  </h3>\n  <p>\n   Salary: $73,200, 000\n  </p>\n </body>\n</html>\n'

# %%
tag_object=soup.title
print("tag object:",tag_object)
# Out:
# tag object: <title>Page Title</title>

# %%
tag_object=soup.h3
tag_object
# Out:
# <h3><b id="boldest">Lebron James</b></h3>

# %%
tag_child =tag_object.b
tag_child
# Out:
# <b id="boldest">Lebron James</b>

# %%
parent_tag=tag_child.parent
parent_tag
# Out:
# <h3><b id="boldest">Lebron James</b></h3>

# %%
sibling_1=tag_object.next_sibling
sibling_1
# Out:
# <p> Salary: $ 92,000,000 </p>

# %%
sibling_2=sibling_1.next_sibling
sibling_2
# Out:
# <h3> Stephen Curry</h3>

# %%
tag_child['id']
# Out:
# 'boldest'

# %%
tag_child.attrs
# Out:
# {'id': 'boldest'}

# %%
tag_child.get('id')
# Out:
# 'boldest'

# %%
# Exam

# %%
Name = 'EMILY'
Name.find('E')
# Out:
# 0

# %%
1/2
# Out:
# 0.5

# %%
'1:2,3:4'.split(':')
# Out:
# ['1', '2,3', '4']
