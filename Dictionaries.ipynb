# %% [markdown]
# # Dictionaries
#
# * denoted by {}
# * Key and values pairs
# * The keys must be immutable and unique
# * The values can immutable, mutable and duplicates
# * example -> dict1 = {"thriller": "1982", "horror": "1950"}
# * using it -> dict1["thriller"], dict1.keys(), ...
